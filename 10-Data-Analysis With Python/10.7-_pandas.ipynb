# %%
import pandas as pd

# %%
df1=pd.read_csv("data.csv")
df2=pd.read_csv("sales1_data.csv")

# %%
df1.head()
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
df2.head()
# Out:
#          Date   Product  Sales Region
# 0  2023-01-01  Product3  738.0   West
# 1  2023-01-02  Product2  868.0  North
# 2  2023-01-03  Product2  554.0   West
# 3  2023-01-04  Product1  618.0  South
# 4  2023-01-05  Product3  501.0   East

# %%
pd.merge(df1,df2,on="Product",how="inner")
# Out:
#          Date_x Category  Value   Product  Sales_x Region_x      Date_y  \
# 0    2023-01-01        A   28.0  Product1    754.0     East  2023-01-04
# 1    2023-01-01        A   28.0  Product1    754.0     East  2023-01-06
# 2    2023-01-01        A   28.0  Product1    754.0     East  2023-01-15
# 3    2023-01-01        A   28.0  Product1    754.0     East  2023-01-16
# 4    2023-01-01        A   28.0  Product1    754.0     East  2023-01-17
# ..          ...      ...    ...       ...      ...      ...         ...
# 420  2023-02-19        C   11.0  Product3    708.0    North  2023-01-13
# 421  2023-02-19        C   11.0  Product3    708.0    North  2023-01-14
# 422  2023-02-19        C   11.0  Product3    708.0    North  2023-01-20
# 423  2023-02-19        C   11.0  Product3    708.0    North  2023-01-22
# 424  2023-02-19        C   11.0  Product3    708.0    North  2023-01-24
#
#      Sales_y Region_y
# 0      618.0    South
# 1        NaN     West
# 2      183.0    South
# ...

# %%
pd.merge(df1,df2,on="Sales",how="outer")
# Out:
#         Date_x Category  Value Product_x  Sales Region_x      Date_y  \
# 0   2023-01-18        C    NaN  Product1  108.0     West         NaN
# 1   2023-01-02        B   39.0  Product3  110.0    North         NaN
# 2          NaN      NaN    NaN       NaN  124.0      NaN  2023-01-19
# 3   2023-02-17        B   69.0  Product3  143.0     West         NaN
# 4   2023-02-09        A   62.0  Product1  155.0     West         NaN
# ..         ...      ...    ...       ...    ...      ...         ...
# 82  2023-02-07        C    2.0  Product1    NaN    North  2023-01-12
# 83  2023-02-07        C    2.0  Product1    NaN    North  2023-01-13
# 84  2023-02-07        C    2.0  Product1    NaN    North  2023-01-17
# 85  2023-02-07        C    2.0  Product1    NaN    North  2023-01-18
# 86  2023-02-07        C    2.0  Product1    NaN    North  2023-01-21
#
#    Product_y Region_y
# 0        NaN      NaN
# 1        NaN      NaN
# 2   Product2    North
# 3        NaN      NaN
# ...

# %%
# Plots in pandas
import matplotlib.pyplot as plt

# %%
air_quality = pd.read_csv("air_quality_no2.csv",index_col=0,parse_dates=True)
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1035 entries, 2019-05-07 02:00:00 to 2019-06-21 02:00:00
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   station_antwerp  95 non-null     float64
#  1   station_paris    1004 non-null   float64
#  2   station_london   969 non-null    float64
# dtypes: float64(3)
# memory usage: 32.3 KB

# %%
air_quality.shape
# Out:
# (1035, 3)

# %%
## Plot the data
air_quality.plot()
plt.show()

# %%
## data from London
air_quality['station_london'].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.scatter(x="station_london",y="station_paris",alpha=0.6)
plt.show()

# %%
air_quality.plot.box()
# Out:
# <Axes: >

# %%
## each columns in a separate subplot
axs = air_quality.plot.area(figsize=(12,4),subplots=True)
plt.show()

# %%
air_quality["london_mg_per_cubic"]=air_quality["station_london"]

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00                 23.0
# 2019-05-07 03:00:00                 19.0
# 2019-05-07 04:00:00                 19.0
# 2019-05-07 05:00:00                 16.0
# 2019-05-07 06:00:00                  NaN

# %%
print(air_quality["station_paris"].mean())
# Out:
# 27.740537848605577

# %%
air_quality[["station_paris","station_london"]].median()
# Out:
# station_paris     24.15
# station_london    25.00
# dtype: float64

# %%
air_quality[["station_paris","station_london"]].describe()
# Out:
#        station_paris  station_london
# count    1004.000000      969.000000
# mean       27.740538       24.777090
# std        15.285746       11.214377
# min         0.000000        0.000000
# 25%        16.500000       19.000000
# 50%        24.150000       25.000000
# 75%        35.925000       31.000000
# max        97.000000       97.000000

# %%
air_quality.agg(
    {
        "station_paris": ["min","max","median","skew"]
    }
)
# Out:
#         station_paris
# min          0.000000
# max         97.000000
# median      24.150000
# skew         1.161128

# %%
air_quality.columns
# Out:
# Index(['station_antwerp', 'station_paris', 'station_london',
#        'london_mg_per_cubic'],
#       dtype='object')

# %%
air_quality.index
# Out:
# DatetimeIndex(['2019-05-07 02:00:00', '2019-05-07 03:00:00',
#                '2019-05-07 04:00:00', '2019-05-07 05:00:00',
#                '2019-05-07 06:00:00', '2019-05-07 07:00:00',
#                '2019-05-07 08:00:00', '2019-05-07 09:00:00',
#                '2019-05-07 10:00:00', '2019-05-07 11:00:00',
#                ...
#                '2019-06-20 17:00:00', '2019-06-20 18:00:00',
#                '2019-06-20 19:00:00', '2019-06-20 20:00:00',
#                '2019-06-20 21:00:00', '2019-06-20 22:00:00',
#                '2019-06-20 23:00:00', '2019-06-21 00:00:00',
#                '2019-06-21 01:00:00', '2019-06-21 02:00:00'],
#               dtype='datetime64[ns]', name='datetime', length=1035, freq=None)
